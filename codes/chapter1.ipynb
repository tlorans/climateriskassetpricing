# %%
# !pip install scienceplots

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(('science','no-latex'))
plt.rcParams['axes.unicode_minus'] = False

# Define the parameters for 10 assets
np.random.seed(42)  # For reproducibility
num_assets = 10
mu = np.random.rand(num_assets)  # Expected returns
Sigma = np.random.rand(num_assets, num_assets)
Sigma = (Sigma + Sigma.T) / 2  # Making the covariance matrix symmetric
np.fill_diagonal(Sigma, 1)  # Setting diagonal elements to 1 for simplicity

# Define ESG characteristics with negative values for brown stocks and positive for green stocks
g = np.random.uniform(-1, 1, num_assets)

a = 1  # Risk aversion coefficient
d_values = [0, 4]  # Different fixed values of ESG taste

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Define the function to calculate the optimal portfolio
def optimal_portfolio(a, d_i):
    b_i = d_i * g
    X_i = (1 / a) * Sigma_inv.dot(mu + (b_i / a))
    return X_i

# Generate optimal portfolios for different d_i values
portfolios = {}

for d_i in d_values:
    X_i = optimal_portfolio(a, d_i)
    portfolios[d_i] = X_i

# Plot the portfolio weights for d_i = 0 and d_i = 4
plt.figure(figsize=(12, 8))

for d_i in d_values:
    X_i = portfolios[d_i]
    plt.scatter(g, X_i, label=f'd_i = {d_i}', s=100, alpha=0.7)

# Highlighting the difference for each stock
for i in range(num_assets):
    plt.plot([g[i], g[i]], [portfolios[0][i], portfolios[4][i]], 'k--', alpha=0.5)

plt.xlabel('ESG Characteristics')
plt.ylabel('Portfolio Weight')
plt.title('Portfolio Weights vs. ESG Characteristics with Different ESG Preferences')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define specific parameters for 10 assets
num_assets = 10
mu = np.array([0.15, 0.10, 0.12, 0.08, 0.09, 0.11, 0.14, 0.07, 0.13, 0.06])  # Expected returns
Sigma = np.array([
    [0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1]
])  # Covariance matrix
g = np.array([-0.8, 0.9, -0.6, 0.7, -0.4, 0.5, -0.3, 0.6, -0.2, 0.4])  # ESG characteristics

a = 2  # Risk aversion coefficient
d_values = [0, 0.5]  # Different fixed values of ESG taste

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Define the function to calculate the optimal portfolio
def optimal_portfolio(a, d_i):
    b_i = d_i * g
    X_i = (1 / a) * Sigma_inv.dot(mu + (b_i / a))
    # normalize the weights to sum up to 1
    X_i = X_i / np.sum(X_i)
    return X_i

# Generate optimal portfolios for different d_i values
portfolios = {}

for d_i in d_values:
    X_i = optimal_portfolio(a, d_i)
    portfolios[d_i] = X_i

# Plot the portfolio weights for d_i = 0 and d_i = 4
plt.figure(figsize=(12, 8))

for d_i in d_values:
    X_i = portfolios[d_i]
    plt.scatter(g, X_i, label=f'd_i = {d_i}', s=100, alpha=0.7)

# # Highlighting the difference for each stock
# for i in range(num_assets):
#     plt.plot([g[i], g[i]], [portfolios[0][i], portfolios[4][i]], 'k--', alpha=0.5)

plt.xlabel('ESG Characteristics')
plt.ylabel('Portfolio Weight')
# plt.title('Portfolio Weights vs. ESG Characteristics with Different ESG Preferences')
plt.legend()
plt.grid(True)
plt.savefig('../images/chapter01/portfolio_weights_vs_esg.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define specific parameters for 10 assets
num_assets = 10
mu = np.array([0.15, 0.10, 0.12, 0.08, 0.09, 0.11, 0.14, 0.07, 0.13, 0.06])  # Expected returns
Sigma = np.array([
    [0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1]
])  # Covariance matrix
g = np.array([-0.8, 0.9, -0.6, 0.7, -0.4, 0.5, -0.3, 0.6, -0.2, 0.4])  # ESG characteristics

a = 2  # Risk aversion coefficient
bar_d_values = np.linspace(0, 0.5, 50)  # Range of values for the wealth-weighted mean of ESG tastes

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Define the function to calculate the market portfolio weights
def market_portfolio_weights(a, bar_d):
    term1 = (1 / a) * Sigma_inv.dot(mu)
    term2 = (1 / a**2) * Sigma_inv.dot(g) * bar_d
    w_m = term1 + term2
    # Normalize the weights to sum up to 1
    w_m = w_m / np.sum(w_m)
    return w_m

# Generate market portfolio weights and calculate w_m^T g for different bar_d values
w_m_dot_g_values = []

for bar_d in bar_d_values:
    w_m = market_portfolio_weights(a, bar_d)
    w_m_dot_g = w_m.T.dot(g)
    w_m_dot_g_values.append(w_m_dot_g)

# Plot the relationship between market greenness w_m^T g and average taste for ESG bar_d
plt.figure(figsize=(14, 8))
plt.plot(bar_d_values, w_m_dot_g_values, marker='o', linestyle='-', color='b')

plt.xlabel('Average Taste for ESG bar d')
plt.ylabel('Market Greenness $w_m^T g$')
# plt.title('Relationship between Market Greenness and Average Taste for ESG')
plt.grid(True)
plt.savefig('../images/chapter01/market_greenness_vs_average_esg_taste.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define specific parameters for 10 assets
num_assets = 10
mu = np.array([0.15, 0.10, 0.12, 0.08, 0.09, 0.11, 0.14, 0.07, 0.13, 0.06])  # Expected returns
Sigma = np.array([
    [0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1]
])  # Covariance matrix
g = np.array([-0.8, 0.9, -0.6, 0.7, -0.4, 0.5, -0.3, 0.6, -0.2, 0.4])  # ESG characteristics

a = 2  # Risk aversion coefficient
bar_d_values = np.linspace(0, 4, 10)  # Range of values for the wealth-weighted mean of ESG tastes

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Define the function to calculate the market portfolio weights
def market_portfolio_weights(a, bar_d):
    term1 = (1 / a) * Sigma_inv.dot(mu)
    term2 = (1 / a**2) * Sigma_inv.dot(g) * bar_d
    w_m = term1 + term2
    return w_m

# Generate market portfolio weights and calculate mu_m for different bar_d values
mu_m_values = []
w_m_dot_g_values = []

for bar_d in bar_d_values:
    w_m = market_portfolio_weights(a, bar_d)
    sigma_m2 = w_m.T.dot(Sigma).dot(w_m)
    w_m_dot_g = w_m.T.dot(g)
    mu_m = a * sigma_m2 - (bar_d / a) * w_m_dot_g
    mu_m_values.append(mu_m)
    w_m_dot_g_values.append(w_m_dot_g)

# Plot the market equity premium mu_m versus w_m^T g
plt.figure(figsize=(14, 8))
plt.plot(w_m_dot_g_values, mu_m_values, marker='o', linestyle='-', color='b')

plt.xlabel('$w_m^T g$ (Greenness of Market Portfolio)')
plt.ylabel('$\mu_m$ (Market Equity Premium)')
# plt.title('Relationship between Market Equity Premium and Greenness of Market Portfolio')
plt.grid(True)
plt.savefig('../images/chapter01/market_equity_premium_vs_greenness.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define specific parameters for 10 assets
num_assets = 10
mu = np.array([0.15, 0.10, 0.12, 0.08, 0.09, 0.11, 0.14, 0.07, 0.13, 0.06])  # Expected returns
Sigma = np.array([
    [0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1]
])  # Covariance matrix
g = np.array([-0.8, 0.9, -0.6, 0.7, -0.4, 0.5, -0.3, 0.6, -0.2, 0.4])  # ESG characteristics

a = 2  # Risk aversion coefficient

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Assume market portfolio is ESG-neutral
w_m = Sigma_inv.dot(mu)
w_m = w_m / np.sum(w_m)
sigma_m2 = w_m.T.dot(Sigma).dot(w_m)
mu_m = a * sigma_m2

# Calculate beta_m
beta_m = Sigma.dot(w_m) / sigma_m2

# Define bar_d values for the two cases
bar_d_values = [0, 0.5]

# Prepare the plot
plt.figure(figsize=(14, 8))

for bar_d in bar_d_values:
    # Proposition 1: Expected excess returns
    expected_excess_returns = mu_m * beta_m - (bar_d / a) * g

    # Corollary 2: Alphas
    alphas = expected_excess_returns - mu_m * beta_m

    # Plot the relationship between alphas and ESG characteristics
    plt.scatter(g, alphas, label=f'$bar d = {bar_d}$', s=100, alpha=0.7)

plt.xlabel('ESG Characteristics $g_n$')
plt.ylabel('Alphas $\\alpha_n$')
# plt.title('Relationship between Alphas and ESG Characteristics')
plt.legend()
plt.grid(True)
plt.axhline(0, color='gray', linewidth=0.5)
plt.savefig('../images/chapter01/alphas_vs_esg_characteristics.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define specific parameters for 10 assets
num_assets = 10
mu = np.array([0.15, 0.10, 0.12, 0.08, 0.09, 0.11, 0.14, 0.07, 0.13, 0.06])  # Expected returns
Sigma = np.array([
    [0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1]
])  # Covariance matrix
g = np.array([-0.8, 0.9, -0.6, 0.7, -0.4, 0.5, -0.3, 0.6, -0.2, 0.4])  # ESG characteristics

a = 2 # Risk aversion coefficient
delta_i_values = np.linspace(0, 4, 10)  # Different values of delta_i

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Calculate market portfolio weights assuming ESG-neutral
w_m = Sigma_inv.dot(mu)
w_m = w_m / np.sum(w_m)

# Calculate \mathbf{1}^T \Sigma^{-1} g
one_T_Sigma_inv_g = np.sum(Sigma_inv.dot(g))

# Define w_g
w_g = Sigma_inv.dot(g) / one_T_Sigma_inv_g

# Calculate the allocation fractions
phi_values = []
market_allocations = []
esg_allocations = []

for delta_i in delta_i_values:
    phi_i = (delta_i / a**2) * one_T_Sigma_inv_g / (1 + (delta_i / a**2) * one_T_Sigma_inv_g)
    phi_values.append(phi_i)
    market_allocations.append(1 - phi_i)
    esg_allocations.append(phi_i)

# Plot the allocation fractions
plt.figure(figsize=(14, 8))

plt.plot(delta_i_values, market_allocations, label='Market Portfolio Allocation', marker='o')
plt.plot(delta_i_values, esg_allocations, label='ESG Portfolio Allocation', marker='s')

plt.xlabel('$\delta_i$ (Investor ESG Preference)')
plt.ylabel('Allocation Fraction')
# plt.title('Allocation Between Market and ESG Portfolio According to $\delta_i$')
plt.legend()
plt.grid(True)
plt.savefig('../images/chapter01/allocation_fractions_vs_delta_i.png', dpi=300)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define specific parameters for 10 assets
num_assets = 10
mu = np.array([0.15, 0.10, 0.12, 0.08, 0.09, 0.11, 0.14, 0.07, 0.13, 0.06])  # Expected returns
Sigma = np.array([
    [0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01, 0.02],
    [0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1, 0.01],
    [0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02, 0.01, 0.1]
])  # Covariance matrix
g = np.array([-0.8, 0.9, -0.6, 0.7, -0.4, 0.5, -0.3, 0.6, -0.2, 0.4])  # ESG characteristics

a = 2 # Risk aversion coefficient
delta_i_values = np.linspace(-1, 0, 10)  # Different values of delta_i

# Calculate the inverse of the covariance matrix
Sigma_inv = np.linalg.inv(Sigma)

# Calculate market portfolio weights assuming ESG-neutral
w_m = Sigma_inv.dot(mu)
w_m = w_m / np.sum(w_m)

# Calculate \mathbf{1}^T \Sigma^{-1} g
one_T_Sigma_inv_g = np.sum(Sigma_inv.dot(g))

# Define w_g
w_g = Sigma_inv.dot(g) / one_T_Sigma_inv_g

# Calculate the allocation fractions
phi_values = []
market_allocations = []
esg_allocations = []

for delta_i in delta_i_values:
    phi_i = (delta_i / a**2) * one_T_Sigma_inv_g / (1 + (delta_i / a**2) * one_T_Sigma_inv_g)
    phi_values.append(phi_i)
    market_allocations.append(1 - phi_i)
    esg_allocations.append(phi_i)

# Plot the allocation fractions
plt.figure(figsize=(14, 8))

plt.plot(delta_i_values, market_allocations, label='Market Portfolio Allocation', marker='o')
plt.plot(delta_i_values, esg_allocations, label='ESG Portfolio Allocation', marker='s')

plt.xlabel('$\delta_i$ (Investor ESG Preference)')
plt.ylabel('Allocation Fraction')
# plt.title('Allocation Between Market and ESG Portfolio According to $\delta_i$')
plt.legend()
plt.grid(True)
plt.savefig('../images/chapter01/allocation_fractions_vs_delta_i_short.png', dpi=300)

plt.show()
